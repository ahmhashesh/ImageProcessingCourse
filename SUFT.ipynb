# %%
import numpy as np
import cv2 as cv

img = cv.imread('files/fig/home.jpg',0)
# Create SURF object. You can specify params here or later.
# Here I set Hessian Threshold to 400
surf = cv.xfeatures2d.SURF_create(400)
# Find keypoints and descriptors directly
kp, des = surf.detectAndCompute(img,None)

# %%
len(kp)
# Out:
# 417

# %%
print( surf.getHessianThreshold() )
# We set it to some 50000. Remember, it is just for representing in picture.
# In actual cases, it is better to have a value 300-500
surf.setHessianThreshold(5000)
# Again compute keypoints and check its number.
kp, des = surf.detectAndCompute(img,None)
print( len(kp) )
# Out:
# 500.0
# 49

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  
img2 = cv.drawKeypoints(img,kp,None,(255,0,0),4)
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x26cc71284a8>, None)

# %% [markdown]
# we can change the Hessian Thresholad and see the effect of it on the number of keypoints

# %%
surf.setHessianThreshold(500)
# Again compute keypoints and check its number.
kp, des = surf.detectAndCompute(img,None)
print( len(kp) )
# Out:
# 349

# %%
img2 = cv.drawKeypoints(img,kp,None,(255,0,0),4)
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x26cd39352b0>, None)
