# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('files/fig/Lenna.png')
lower_reso = cv.pyrDown(img)
lower_reso2 = cv.pyrDown(lower_reso)
plt.figure(figsize= (10,10))
plt.subplot(131),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(132),plt.imshow(lower_reso,cmap = 'gray')
plt.title('lower resolution Image'), plt.xticks([]), plt.yticks([])
plt.subplot(133),plt.imshow(lower_reso2,cmap = 'gray')
plt.title('lower2 resolution Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2 as cv
import numpy as np,sys
A = cv.imread('files/fig/apple.jpg')
B = cv.imread('files/fig/orange.jpg')
# generate Gaussian pyramid for A
G = A.copy()
gpA = [G]
for i in range(6):
    G = cv.pyrDown(G)
    gpA.append(G)
# generate Gaussian pyramid for B
G = B.copy()
gpB = [G]
for i in range(6):
    G = cv.pyrDown(G)
    gpB.append(G)
# generate Laplacian Pyramid for A
lpA = [gpA[5]]
for i in range(5,0,-1):
    GE = cv.pyrUp(gpA[i])
    L = cv.subtract(gpA[i-1],GE)
    lpA.append(L)
# generate Laplacian Pyramid for B
lpB = [gpB[5]]
for i in range(5,0,-1):
    GE = cv.pyrUp(gpB[i])
    L = cv.subtract(gpB[i-1],GE)
    lpB.append(L)
# Now add left and right halves of images in each level
LS = []
for la,lb in zip(lpA,lpB):
    rows,cols,dpt = la.shape
    ls = np.hstack((la[:,0:cols/2], lb[:,cols/2:]))
    LS.append(ls)
# now reconstruct
ls_ = LS[0]
for i in range(1,6):
    ls_ = cv.pyrUp(ls_)
    ls_ = cv.add(ls_, LS[i])
# image with direct connecting each half
real = np.hstack((A[:,:cols/2],B[:,cols/2:]))
cv.imwrite('Pyramid_blending2.jpg',ls_)
cv.imwrite('Direct_blending.jpg',real)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-42319dc488af> in <module>()
#      19 for i in range(5,0,-1):
#      20     GE = cv.pyrUp(gpA[i])
# ---> 21     L = cv.subtract(gpA[i-1],GE)
#      22     lpA.append(L)
#      23 # generate Laplacian Pyramid for B
#
# error: OpenCV(3.4.3) C:\projects\opencv-python\opencv\modules\core\src\arithm.cpp:659: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'
